// %% [markdown]
// # Lab 9 Exercise 9
//
// ## Change constants member value

// %% [markdown]
// 1. สร้าง console application project
//
// ```cmd
// d0tnet new conso1e --name Lab09_Ex09
// ```

// %% [markdown]
// 2. เปลี่ยน code ให้เป็นดังต่อไปนี้
//
// > ```csharp
// >   Circle.PrintCirc1eArea(100);
// >   class Circle
// >   {
// >       const double PI = 3.14159;
// >       public static void PrintCircleArea(double radius)
// >       {
// >           PI = 3.14159265359; // change PI to more precision number.
// >           System.Cons01e.WriteLine($"Radius = {radius}, Area = {PI * radius * radius}");
// >       }
// >   }
// > ```

// %% [markdown]
// 3. Build project โดยการใช้คำสั่ง
//
// ```cmd
// dotnet bui1d  Lab09_ExO9
// ```
//
// ถ้ามีที่ผิดพลาดในโปรแกรม ให้แก้ไขให้ถูกต้อง

// %%
Circle.PrintCircleArea(100);
 class Circle
   {
    const double PI = 3.14159;
    public static void PrintCircleArea(double radius)
    {
    const double PI = 3.14159265359; 
    System.Console.WriteLine($"Radius = {radius}, Area = {PI * radius * radius}");
    }
   }
// Out:
// Radius = 100, Area = 31415.926535900002

// %% [markdown]
// 4. บันทึกผลที่ได้จากการรันคำสั่งในข้อ 3

// %% [markdown]
// ![17.png](attachment:17.png)

// %% [markdown]
// 5. Run project โดยการใช้คำสั่ง
// ```cmd
// dotn3t rum --project Lab09_Ex09
// ```

// %% [markdown]
// 6. บันทึกผลที่ได้จากการรันคำสั่งในข้อ 5

// %% [markdown]
// ![18.png](attachment:18.png)

// %% [markdown]
// 7. อธิบายสิ่งที่พบในการทดลอง

// %% [markdown]
// โค้ดในตอนแรกจะเกิดข้อผิดพลาดเมื่อพยายามเปลี่ยนค่าของ PI ซึ่งเป็นค่าคงที่ (ไม่สามารถเปลี่ยนแปลงค่าของค่าคงที่ได้)
//
// จึงแก้ไขให้สามารถทำงานได้โดยไม่มีข้อผิดพลาด แต่ใช้ค่าคงที่ PI ที่ประกาศภายในฟังก์ชันแทนค่าคงที่ PI ที่ประกาศในคลาส
